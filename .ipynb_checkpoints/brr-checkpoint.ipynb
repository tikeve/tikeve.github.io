# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
import sys
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()
    
    sys.argv = ['', 'full']
    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# System var is - full
# 	Downloading FPL tables is over.	 It takes 149.18565344810486 sec
#
# 	Checking equalities is over.	 It takes 0.5696008205413818 sec
#
# 	data_collection_type = full
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\missing.py:48: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
# 	Creating tables is over.	 It takes 34.918747425079346 sec
#
# inputFPL is over.	 It takes 184.67500233650208 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 51.66478228569031 sec
# 	 All Columns Added.	 It takes 0.5646753311157227 sec
# inputUnderstat is over.	 It takes 52.22945761680603 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.10593914985656738 sec
# 	 2. Constants and Functions are over.	 It takes 0.0019989013671875 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.3919191360473633 sec
# 		 3.2. Team_xA is over.	 It takes 0.37677860260009766 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.37578749656677246 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.017987489700317383 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.019988059997558594 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.0179898738861084 sec
# 		 3.7. TableTeams is over.	 It takes 0.003997802734375 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 11.09766173362732 sec
# 		 4.2. Player_xA is over.	 It takes 11.22555947303772 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.3448026180267334 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.33680105209350586 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 1.4671742916107178 sec
# 		 5.2. Visualizing futures.	 It takes 0.01898932456970215 sec
# 	 6. Writing to files is over.	 It takes 22.688525438308716 sec
# FPL is created./t It takes 48.49593424797058 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.07495737075805664 sec
# 	 2. Constants and Functions are over.	 It takes 0.0030035972595214844 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.39775729179382324 sec
# 		 3.2. Team_xA is over.	 It takes 0.37780094146728516 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3777902126312256 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.03296518325805664 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.020989179611206055 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.020003557205200195 sec
# 		 3.7. TableTeams is over.	 It takes 0.003983259201049805 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 10.628934383392334 sec
# 		 4.2. Player_xA is over.	 It takes 10.035263299942017 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.32581400871276855 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.34079527854919434 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 1.5384199619293213 sec
# 		 5.2. Visualizing futures.	 It takes 0.01699066162109375 sec
# 	 6. Writing to files is over.	 It takes 20.87406849861145 sec
# Understat is created./t It takes 45.07153391838074 sec
# 	 FPL Testing is over.	 It takes 0.2018883228302002 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 5.002136945724487 sec
#
#
# The whole program working time is  335.6929168701172
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
