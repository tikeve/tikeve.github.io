# %%
''' Main file

    Main module. Runs program(), does some testing, sends mistakes on mail and telegram
    
    
    Uses 3 modules: inputFPL, inputUnderstat, Source
    
    inputFPL downloads data from https://fantasy.premierleague.com/
    inputUnderstat downloads data from https://understat.com/
    Source converts data to suitable pandas tables correctness by running source.test function.
    
    
    Uses no data

'''


# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
import sys
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()
    
    sys.argv = ['', '*']
    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# System var is - *
# 		data_collection_type = medium
#
# Medium Fixtures data has changed:
#      finished_provisional  minutes  stats
# 180                 False    False  False
# Medium Players data has changed:
#      minutes  points_per_game
# 134    False            False
# 138    False             True
# 139    False             True
# 146    False             True
# 147    False             True
# 148    False             True
# 149    False             True
# 151    False             True
# 154    False             True
# 155    False             True
# 157    False             True
# 231    False             True
# 232    False             True
# 238    False            False
# 240    False             True
# 241    False             True
# 243    False             True
# 246    False             True
# 247    False             True
# 249    False            False
# 250    False             True
# 251    False             True
# 252    False             True
# 	Checking equalities is over.	 It takes 5.654057741165161 sec
#
# 	data_collection_type = medium
#
# 	Downloading FPL tables is over.	 It takes 159.64672660827637 sec
#
# 	Creating tables is over.	 It takes 38.038533210754395 sec
#
# inputFPL is over.	 It takes 203.34030747413635 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 63.512794971466064 sec
# 	 All Columns Added.	 It takes 0.9994289875030518 sec
# inputUnderstat is over.	 It takes 64.51422238349915 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.17889857292175293 sec
# 	 2. Constants and Functions are over.	 It takes 0.0029976367950439453 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.5117099285125732 sec
# 		 3.2. Team_xA is over.	 It takes 0.5896623134613037 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.5546822547912598 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.024985313415527344 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.02698493003845215 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.0219876766204834 sec
# 		 3.7. TableTeams is over.	 It takes 0.003997087478637695 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 13.044272184371948 sec
# 		 4.2. Player_xA is over.	 It takes 12.12852144241333 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.41174960136413574 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.3798215389251709 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 1.474168062210083 sec
# 		 5.2. Visualizing futures.	 It takes 0.017993927001953125 sec
# 	 6. Writing to files is over.	 It takes 24.285813331604004 sec
# FPL is created./t It takes 53.660250425338745 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.17989730834960938 sec
# 	 2. Constants and Functions are over.	 It takes 0.0019986629486083984 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.41376447677612305 sec
# 		 3.2. Team_xA is over.	 It takes 0.408766508102417 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3987765312194824 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.022986173629760742 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.020998239517211914 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.019988536834716797 sec
# 		 3.7. TableTeams is over.	 It takes 0.003997325897216797 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 11.986155271530151 sec
# 		 4.2. Player_xA is over.	 It takes 11.505179643630981 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.3707878589630127 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.38178181648254395 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 1.4461743831634521 sec
# 		 5.2. Visualizing futures.	 It takes 0.0179903507232666 sec
# 	 6. Writing to files is over.	 It takes 24.134328603744507 sec
# Understat is created./t It takes 51.31455707550049 sec
# 	 FPL Testing is over.	 It takes 0.21987485885620117 sec
#                         player  element  fixture  minutes  FPL_minutes
# 0       Daniel Castelo Podence    469.0       89       80           69
# 1                  Fabio Silva    504.0       89       74           63
# 2   David Luiz Moreira Marinho      3.0       89       56           45
# 3      Willian Borges Da Silva    478.0       89       75           64
# 4                  Rob Holding     16.0       89       34           45
# ..                         ...      ...      ...      ...          ...
# 78                Jarrod Bowen    445.0      187       83            0
# 79               Said Benrahma    587.0      187       69            0
# 80               Pablo Fornals    450.0      187       90            0
# 81             Michail Antonio    437.0      187       90            0
# 82              Manuel Lanzini    439.0      187       21            0
#
# [83 rows x 5 columns]
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 5.833570718765259 sec
#
#
# The whole program working time is  378.88778614997864
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
