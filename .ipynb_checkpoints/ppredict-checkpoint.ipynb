# %%
import pandas as pd
import numpy as np
import catboost

# %%
df = pd.read_csv('mid/FPL/TxG.csv')
df
# Out:
#       GW1    GW2    GW3    GW4    GW5    GW6    GW7    GW8    GW9   GW10  ...  \
# 0   208.0   80.0   14.0  384.0  151.0  166.0  102.0  238.0  309.0  179.0  ...
# 1   113.0  113.0  108.0  280.0  185.0  104.0  220.0  156.0  116.0  118.0  ...
# 2   113.0  143.0  138.0   58.0  108.0  196.0  199.0  295.0  198.0  141.0  ...
# 3   208.0  179.0  129.0   70.0  152.0  115.0  193.0  170.0  136.0  128.0  ...
# 4   121.0  119.0  160.0  125.0  178.0  100.0  223.0   83.0   95.0  160.0  ...
# 5   155.0  336.0  105.0  114.0  371.0   72.0  323.0   66.0  255.0  218.0  ...
# 6    57.0   55.0  146.0  237.0  144.0  112.0  218.0   82.0  216.0   80.0  ...
# 7   220.0  191.0  168.0  164.0  147.0  172.0  131.0  157.0  210.0  206.0  ...
# 8   101.0   65.0   99.0   90.0  193.0  342.0  113.0  336.0  102.0  226.0  ...
# 9    60.0  186.0  160.0  140.0  221.0  205.0  208.0   41.0  213.0  161.0  ...
# 10  258.0  377.0  305.0  453.0  379.0  203.0  139.0  290.0  253.0  181.0  ...
# ...
