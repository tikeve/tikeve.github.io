# %%
import pandas as pd
from pathlib import Path
from Source import write_table

try:
    Table = pd.read_csv(Path('in/Table_FPL.csv'))
except:
    folder = ''
    Teams = pd.read_csv(Path(f'{folder}in/Teams.csv'))
    Players = pd.read_csv(Path(f'{folder}in/Players.csv'))

    for source in ['FPL', 'Understat']:
#         TxG.to_csv(Path(f'{folder}mid/{source}/TxG.csv'), index=False)
#         TxA.to_csv(Path(f'{folder}mid/{source}/TxA.csv'), index=False)
#         TOxG.to_csv(Path(f'{folder}mid/{source}/TOxG.csv'), index=False)
#         TxGA.to_csv(Path(f'{folder}mid/{source}/TxGA.csv'), index=False)
#         TxAA.to_csv(Path(f'{folder}mid/{source}/TxAA.csv'), index=False)
#         TOxGA.to_csv(Path(f'{folder}mid/{source}/TOxGA.csv'), index=False)
#         PxG.to_csv(Path(f'{folder}mid/{source}/PxG.csv'), index=False)
#         PxA.to_csv(Path(f'{folder}mid/{source}/PxA.csv'), index=False)
#         PxGA.to_csv(Path(f'{folder}mid/{source}/PxGA.csv'), index=False)
#         PxAA.to_csv(Path(f'{folder}mid/{source}/PxAA.csv'), index=False)

#         TxxG.to_csv(Path(f'{folder}mid/{source}/TxxG.csv'), index=False)
#         TxxA.to_csv(Path(f'{folder}mid/{source}/TxxA.csv'), index=False)
#         TxOxG.to_csv(Path(f'{folder}mid/{source}/TxOxG.csv'), index=False)
#         PxxG.to_csv(Path(f'{folder}mid/{source}/PxxG.csv'), index=False)
#         PxxA.to_csv(Path(f'{folder}mid/{source}/PxxA.csv'), index=False)
#         PxOxG.to_csv(Path(f'{folder}mid/{source}/PxOxG.csv'), index=False)


        TxG = pd.DataFrame()
#         class_args = [Teams, Players, TAwu, TDwu, PAwu]
#         class_args += [self.source, self.ma_num, folder]
        class_args = [Teams, Players, 0, 0, 0, 0, 0, 0]
#         A = write_table(TxG, 'Team_xG', 'xG av', TxG, 100, 0, class_args)
        
#         del Teams['id']
#         del Players['web_name']
#         del Players['Team number']
        
        Teams.columns = ['id','Teams', 'xG av', 'Matches']
        A = write_table(Teams, 'Team_xG', 'xG av', TxG, 100, 0, class_args)
        Teams.to_csv(Path(f'{folder}out/{source}/Team_xG.csv'), index=False)
        Teams.columns = ['Teams', 'xA av', 'Matches']
        Teams.to_csv(Path(f'{folder}out/{source}/Team_xA.csv'), index=False)
        Teams.columns = ['Teams', 'Opponent xG av', 'Matches']
        Teams.to_csv(Path(f'{folder}out/{source}/Team_Opponent_xG.csv'), index=False)
        Teams.columns = ['Teams', 'xG av adj', 'Matches']
        Teams.to_csv(Path(f'{folder}out/{source}/Tema_xG_Ad.csv'), index=False)
        Teams.columns = ['Teams', 'xA av adj', 'Matches']
        Teams.to_csv(Path(f'{folder}out/{source}/Team_xA_Ad.csv'), index=False)
        Teams.columns = ['Teams', 'Opponent xG av adj', 'Matches']
        Teams.to_csv(Path(f'{folder}out/{source}/Team_Opponent_xG_Ad.csv'), index=False)
        #Players.columns = ['Name', 'Team', 'Position']
        Players.to_csv(Path(f'{folder}out/{source}/Player_xG.csv'), index=False)
        Players.to_csv(Path(f'{folder}out/{source}/Player_xA.csv'), index=False)
        Players.to_csv(Path(f'{folder}out/{source}/Player_xG_Ad.csv'), index=False)
        Players.to_csv(Path(f'{folder}out/{source}/Player_xA_Ad.csv'), index=False)
        

    
    print("Table_FPL is empty or can't be read")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-3-93ca8c1b52bb> in <module>
#       5 try:
# ----> 6     Table = pd.read_csv(Path('in/Table_FPL.csv'))
#       7 except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     945
# --> 946         self._make_engine(self.engine)
#     947
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-93ca8c1b52bb> in <module>
#      41
#      42         Teams.columns = ['id','Teams', 'xG av', 'Matches']
# ---> 43         A = write_table(Teams, 'Team_xG', 'xG av', TxG, 100, 0, class_args)
#      44         Teams.to_csv(Path(f'{folder}out/{source}/Team_xG.csv'), index=False)
#      45         Teams.columns = ['Teams', 'xA av', 'Matches']
#
# c:\Users\const\Documents\GitHub\tikeve.github.io\Source.py in write_table(df, name, key_col, xdf, df_n, xdf_n, class_args)
#     599         F_UF = pd.DataFrame()
#     600         for i in df.columns:
# --> 601             F_UF[i]=[np.nan if np.isnan(xdf.at[j,i])&np.isnan(df.at[j,i]) else 1 for j in df.index]
#     602             F_UF[i] = [np.nan if np.isnan(F_UF.at[j,i]) else 1 if np.isnan(xdf.at[j,i]) else 0 for j in df.index]
#     603
#
# c:\Users\const\Documents\GitHub\tikeve.github.io\Source.py in <listcomp>(.0)
#     599         F_UF = pd.DataFrame()
#     600         for i in df.columns:
# --> 601             F_UF[i]=[np.nan if np.isnan(xdf.at[j,i])&np.isnan(df.at[j,i]) else 1 for j in df.index]
#     602             F_UF[i] = [np.nan if np.isnan(F_UF.at[j,i]) else 1 if np.isnan(xdf.at[j,i]) else 0 for j in df.index]
#     603
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2078             return self.obj.loc[key]
#    2079
# -> 2080         return super().__getitem__(key)
#    2081
#    2082     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2025
#    2026         key = self._convert_key(key)
# -> 2027         return self.obj._get_value(*key, takeable=self._takeable)
#    2028
#    2029     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3004             return series._values[index]
#    3005
# -> 3006         series = self._get_item_cache(col)
#    3007         engine = self.index._engine
#    3008
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    3538             #  pending resolution of GH#33047
#    3539
# -> 3540             loc = self.columns.get_loc(item)
#    3541             values = self._mgr.iget(loc)
#    3542             res = self._box_col_values(values, loc)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'id'

# %%
Teams
# Out:
#              Teams  Opponent xG av adj  Matches
# 0          Arsenal                 0.0        0
# 1      Aston Villa                 0.0        0
# 2        Brentford                 0.0        0
# 3         Brighton                 0.0        0
# 4          Burnley                 0.0        0
# 5          Chelsea                 0.0        0
# 6   Crystal Palace                 0.0        0
# 7          Everton                 0.0        0
# 8        Leicester                 0.0        0
# 9            Leeds                 0.0        0
# 10       Liverpool                 0.0        0
# 11        Man City                 0.0        0
# 12         Man Utd                 0.0        0
# 13       Newcastle                 0.0        0
# 14         Norwich                 0.0        0
# 15     Southampton                 0.0        0
# 16           Spurs                 0.0        0
# 17         Watford                 0.0        0
# 18        West Ham                 0.0        0
# 19          Wolves                 0.0        0
