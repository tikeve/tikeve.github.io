# %%
import sklearn
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
from pathlib import Path
from Brr_functions import no_lists
import json

# %%
with open(Path('mid/FPL/Team_xG.txt'), 'r') as file:
    Team_xG = pd.DataFrame(json.loads(file.read()))
    Team_xG.index = pd.to_numeric(Team_xG.index)
    Team_xG = Team_xG.sort_index()
    
with open(Path('mid/FPL/Team_oppdefence_coeff.txt'), 'r') as file:
    Team_oppdefence_coeff = pd.DataFrame(json.loads(file.read()))
    Team_oppdefence_coeff.index = pd.to_numeric(Team_oppdefence_coeff.index)
    Team_oppdefence_coeff = Team_oppdefence_coeff.sort_index()

# %%
df = no_lists(Team_xG.sort_index())#sort_index doesn't matter as it adds column to suited index anyway


X = df[df.columns[5:-1]].copy()
X['opp_def'] = Team_oppdefence_coeff['GW8']#*threatAllowedAv
Y = df['GW8']
reg = LinearRegression().fit(X, Y)
display(reg.score(X, Y))
display(reg.coef_)

X = df[df.columns[5:-1]].copy()
X['sum'] = X.sum(axis=1)/6
X['opp_def'] = Team_oppdefence_coeff['GW8']#*threatAllowedAv
X = X[X.columns[-2:]]
display(X)
Y = df['GW8']
reg = LinearRegression().fit(X, Y)
display(reg.score(X, Y))
display(reg.coef_)
# Out:
# 0.6742185084043917
# array([ 4.64920716e-01, -1.57130994e-01,  1.91095219e-01, -4.88416964e-03,
#         3.72324867e-01, -1.04303741e-01,  2.19952894e+02])
#            sum   opp_def
# 0   113.666667  1.032592
# 1   218.166667  0.811579
# 2   158.500000  1.267640
# 3   117.333333  0.610652
# 4   179.833333  1.091959
# 5   139.666667  1.197326
# 6   175.500000  0.915614
# 7   152.333333  0.990223
# 8   141.333333  0.980720
# 9   202.166667  1.090697
# 10  236.833333  0.755461
# 11  200.166667  0.726282
# 12  169.333333  1.043883
# 13  100.000000  0.860172
# 14  107.000000  0.778694
# 15  130.666667  1.383978
# 16  207.333333  1.237933
# 17  102.666667  0.967556
# 18  142.666667  1.284487
# 19  127.833333  0.968966
# 0.47285028646828764
# array([  0.81738501, 215.03675772])
