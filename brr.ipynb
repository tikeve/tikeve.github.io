# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 218.32335209846497 sec
# 	 Fixtures are over.	 It takes 14.943786144256592 sec
# inputFPL is over.	 It takes 234.4174666404724 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 60.791839361190796 sec
# 	 All Columns Added.	 It takes 1.6830027103424072 sec
# inputUnderstat is over.	 It takes 62.479841470718384 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 2.5210025310516357 sec
# 	 2. Constants and Functions are over.	 It takes 0.007996082305908203 sec
# 	 3. Calculating team tables
# 		 3.1. TeamThreat is over.	 It takes 0.6715869903564453 sec
# 		 3.2. TeamCreativity is over.	 It takes 1.3591597080230713 sec
# 		 3.3. TeamDefence is over.	 It takes 0.5716490745544434 sec
# 		 3.4. TeamThreatAd is over.	 It takes 0.06296062469482422 sec
# 		 3.5. TeamCreativityAd is over.	 It takes 0.035976409912109375 sec
# 		 3.6. TeamDefenceAd is over.	 It takes 0.032979488372802734 sec
# 		 3.7. TableTeams is over.	 It takes 0.010996103286743164 sec
# 	 4. Calculating player tables
# 		 4.1. PlayerThreat is over.	 It takes 25.213459730148315 sec
# 		 4.2. PlayerCreativity is over.	 It takes 43.3444402217865 sec
# 		 4.3. PlayerThreatAd is over.	 It takes 1.729931116104126 sec
# 		 4.4. PlayerCreativityAd is over.	 It takes 1.8058865070343018 sec
# 	 5. Writing to files is over.	 It takes 135.2731990814209 sec
# FPL is created./t It takes 212.65221905708313 sec
#
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.4749581813812256 sec
# 	 2. Constants and Functions are over.	 It takes 0.0329742431640625 sec
# 	 3. Calculating team tables
# 		 3.1. TeamThreat is over.	 It takes 0.6615898609161377 sec
# 		 3.2. TeamCreativity is over.	 It takes 0.24285054206848145 sec
# 		 3.3. TeamDefence is over.	 It takes 0.2258625030517578 sec
# 		 3.4. TeamThreatAd is over.	 It takes 0.016986846923828125 sec
# 		 3.5. TeamCreativityAd is over.	 It takes 0.015990257263183594 sec
# 		 3.6. TeamDefenceAd is over.	 It takes 0.015990018844604492 sec
# 		 3.7. TableTeams is over.	 It takes 0.0059967041015625 sec
# 	 4. Calculating player tables
# 		 4.1. PlayerThreat is over.	 It takes 12.127527713775635 sec
# 		 4.2. PlayerCreativity is over.	 It takes 10.140752077102661 sec
# 		 4.3. PlayerThreatAd is over.	 It takes 1.2822067737579346 sec
# 		 4.4. PlayerCreativityAd is over.	 It takes 0.5166785717010498 sec
# 	 5. Writing to files is over.	 It takes 66.81969261169434 sec
# Understat is created./t It takes 92.58105635643005 sec
#
# 	 FPL Testing is over.	 It takes 0.7195639610290527 sec
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 4.953040599822998 sec
# The whole program working time is  607.8872368335724
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
