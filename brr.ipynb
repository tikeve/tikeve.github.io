# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 242.24061107635498 sec
# 	 Fixtures are over.	 It takes 36.90535545349121 sec
# inputFPL is over.	 It takes 285.36048340797424 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 81.79223823547363 sec
# 	 All Columns Added.	 It takes 0.9877331256866455 sec
# inputUnderstat is over.	 It takes 82.78096985816956 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.348036527633667 sec
# 	 2. Constants and Functions are over.	 It takes 0.007990598678588867 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.9224417209625244 sec
# 		 3.2. Team_xA is over.	 It takes 0.5906367301940918 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.38976073265075684 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.025984525680541992 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.026981115341186523 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.024985551834106445 sec
# 		 3.7. TableTeams is over.	 It takes 0.07343697547912598 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 14.991366624832153 sec
# 		 4.2. Player_xA is over.	 It takes 14.834858417510986 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.9817314147949219 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.9604067802429199 sec
# 	 5. Writing to files is over.	 It takes 83.62225317955017 sec
# FPL is created./t It takes 117.80685639381409 sec
#
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.29781484603881836 sec
# 	 2. Constants and Functions are over.	 It takes 0.02098703384399414 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.5456662178039551 sec
# 		 3.2. Team_xA is over.	 It takes 0.33778834342956543 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.34578704833984375 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.039977073669433594 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.07795190811157227 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.06395959854125977 sec
# 		 3.7. TableTeams is over.	 It takes 0.013995885848999023 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 13.589625597000122 sec
# 		 4.2. Player_xA is over.	 It takes 13.862457990646362 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.5266766548156738 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.1912615299224854 sec
# 	 5. Writing to files is over.	 It takes 66.4675726890564 sec
# Understat is created./t It takes 97.38851571083069 sec
#
# 	 FPL Testing is over.	 It takes 0.4000980854034424 sec
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 6.723728656768799 sec
# The whole program working time is  590.557302236557
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
