# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
import sys
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()
    
    sys.argv = ['', '*']
    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# System var is - full
# 	Downloading FPL tables is over.	 It takes 244.07403326034546 sec
#
# 	Creating tables is over.	 It takes 68.35882043838501 sec
#
# inputFPL is over.	 It takes 312.43285369873047 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 152.99833965301514 sec
# 	 All Columns Added.	 It takes 1.856856107711792 sec
# inputUnderstat is over.	 It takes 154.85519576072693 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 1.2370705604553223 sec
# 	 2. Constants and Functions are over.	 It takes 0.020982980728149414 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.4301187992095947 sec
# 		 3.2. Team_xA is over.	 It takes 1.892833948135376 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.666973352432251 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.13103461265563965 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.06595993041992188 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.05796170234680176 sec
# 		 3.7. TableTeams is over.	 It takes 0.02498602867126465 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 49.70733141899109 sec
# 		 4.2. Player_xA is over.	 It takes 32.78481125831604 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.808887004852295 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.771906852722168 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 6.659533739089966 sec
# 		 5.2. Visualizing futures.	 It takes 0.05517101287841797 sec
# 	 6. Writing to files is over.	 It takes 204.2290849685669 sec
# FPL is created./t It takes 303.54764580726624 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.7875223159790039 sec
# 	 2. Constants and Functions are over.	 It takes 0.00798344612121582 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 2.335639238357544 sec
# 		 3.2. Team_xA is over.	 It takes 1.973768949508667 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.5734076499938965 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.06795883178710938 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.08794546127319336 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.12991857528686523 sec
# 		 3.7. TableTeams is over.	 It takes 0.010992050170898438 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 34.248698711395264 sec
# 		 4.2. Player_xA is over.	 It takes 39.84452199935913 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.7816851139068604 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.2361295223236084 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 7.769397258758545 sec
# 		 5.2. Visualizing futures.	 It takes 0.048967599868774414 sec
# 	 6. Writing to files is over.	 It takes 138.14480900764465 sec
# Understat is created./t It takes 230.05833673477173 sec
# 	 FPL Testing is over.	 It takes 0.8884406089782715 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 15.79425835609436 sec
#
#
# The whole program working time is  1017.6279575824738
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
