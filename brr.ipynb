# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 178.53517508506775 sec
# 	 Fixtures are over.	 It takes 34.896509885787964 sec
# inputFPL is over.	 It takes 214.95353937149048 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 59.27309560775757 sec
# 	 All Columns Added.	 It takes 0.5398023128509521 sec
# inputUnderstat is over.	 It takes 59.81289792060852 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.8707785606384277 sec
# 	 2. Constants and Functions are over.	 It takes 0.006991863250732422 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.39578843116760254 sec
# 		 3.2. Team_xA is over.	 It takes 0.3587775230407715 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3867604732513428 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.09918403625488281 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.02597808837890625 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.026984214782714844 sec
# 		 3.7. TableTeams is over.	 It takes 0.018368959426879883 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 9.865923881530762 sec
# 		 4.2. Player_xA is over.	 It takes 9.581094741821289 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.5102806091308594 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.5206832885742188 sec
# 	 4.99. Creating future tables and opponent tables is over.	 It takes 4.0009191036224365 sec
# 	 5. Writing to files is over.	 It takes 70.57387447357178 sec
# FPL is created./t It takes 97.24438691139221 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.382249116897583 sec
# 	 2. Constants and Functions are over.	 It takes 0.006993532180786133 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.3957545757293701 sec
# 		 3.2. Team_xA is over.	 It takes 0.5426690578460693 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.36577486991882324 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.025983810424804688 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.02498459815979004 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.03497719764709473 sec
# 		 3.7. TableTeams is over.	 It takes 0.005995988845825195 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 10.975241661071777 sec
# 		 4.2. Player_xA is over.	 It takes 10.121764898300171 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.832486629486084 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.6545953750610352 sec
# 	 4.99. Creating future tables and opponent tables is over.	 It takes 5.942350387573242 sec
# 	 5. Writing to files is over.	 It takes 131.15229392051697 sec
# Understat is created./t It takes 161.4661054611206 sec
# 	 FPL Testing is over.	 It takes 0.8234796524047852 sec
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 12.939027786254883 sec
#
#
# The whole program working time is  547.3125081062317
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
