# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 211.56398630142212 sec
# 	 Fixtures are over.	 It takes 35.10041403770447 sec
# inputFPL is over.	 It takes 248.16047978401184 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 77.17574739456177 sec
# 	 All Columns Added.	 It takes 0.5256736278533936 sec
# inputUnderstat is over.	 It takes 77.70242404937744 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.37043142318725586 sec
# 	 2. Constants and Functions are over.	 It takes 0.008990764617919922 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.013378381729126 sec
# 		 3.2. Team_xA is over.	 It takes 0.3707692623138428 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3547861576080322 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.10109972953796387 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.02298736572265625 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.02498316764831543 sec
# 		 3.7. TableTeams is over.	 It takes 0.005997657775878906 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 13.753544569015503 sec
# 		 4.2. Player_xA is over.	 It takes 13.310820579528809 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.6965641975402832 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.538665771484375 sec
# 	 5. Writing to files is over.	 It takes 76.50536465644836 sec
# FPL is created./t It takes 107.08536911010742 sec
#
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.2286531925201416 sec
# 	 2. Constants and Functions are over.	 It takes 0.019979476928710938 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.859471321105957 sec
# 		 3.2. Team_xA is over.	 It takes 0.352783203125 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.32350897789001465 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.028981924057006836 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.023984193801879883 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.022986173629760742 sec
# 		 3.7. TableTeams is over.	 It takes 0.006998538970947266 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 15.548979759216309 sec
# 		 4.2. Player_xA is over.	 It takes 12.997180938720703 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.0854620933532715 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.5377011299133301 sec
# 	 5. Writing to files is over.	 It takes 68.15839624404907 sec
# Understat is created./t It takes 100.19606804847717 sec
#
# 	 FPL Testing is over.	 It takes 0.4387247562408447 sec
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 7.3860695362091064 sec
# The whole program working time is  541.0570869445801
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
