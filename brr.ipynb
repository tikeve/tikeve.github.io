# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 248.6587278842926 sec
# 	 Fixtures are over.	 It takes 52.86935901641846 sec
# inputFPL is over.	 It takes 303.6464092731476 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 89.41626071929932 sec
# 	 All Columns Added.	 It takes 1.0273644924163818 sec
# inputUnderstat is over.	 It takes 90.4436252117157 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.43673133850097656 sec
# 	 2. Constants and Functions are over.	 It takes 0.013991355895996094 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.2762377262115479 sec
# 		 3.2. Team_xA is over.	 It takes 0.535668134689331 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.8818471431732178 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.10293912887573242 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.10393404960632324 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.130324125289917 sec
# 		 3.7. TableTeams is over.	 It takes 0.0379788875579834 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 22.28709626197815 sec
# 		 4.2. Player_xA is over.	 It takes 16.55147671699524 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.6625950336456299 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.0467467308044434 sec
# 	 5. Writing to files is over.	 It takes 129.12661623954773 sec
# FPL is created./t It takes 173.19917798042297 sec
#
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.10893106460571289 sec
# 	 2. Constants and Functions are over.	 It takes 0.007995128631591797 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.38569211959838867 sec
# 		 3.2. Team_xA is over.	 It takes 1.1065688133239746 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.4737064838409424 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.030981779098510742 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.028983116149902344 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.03997492790222168 sec
# 		 3.7. TableTeams is over.	 It takes 0.011993169784545898 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 15.82284927368164 sec
# 		 4.2. Player_xA is over.	 It takes 14.303198337554932 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.6765873432159424 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.0487165451049805 sec
# 	 5. Writing to files is over.	 It takes 75.55692172050476 sec
# Understat is created./t It takes 109.60910034179688 sec
#
# 	 FPL Testing is over.	 It takes 0.8713283538818359 sec
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 12.578755855560303 sec
# The whole program working time is  690.4450228214264
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
