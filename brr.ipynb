# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
import sys
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()
    
    sys.argv = ['', 'full']
    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# System var is - full
# 	Downloading FPL tables is over.	 It takes 273.33186078071594 sec
#
# 	Creating tables is over.	 It takes 108.0823245048523 sec
#
# inputFPL is over.	 It takes 381.4151887893677 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 135.24449372291565 sec
# 	 All Columns Added.	 It takes 1.033689260482788 sec
# inputUnderstat is over.	 It takes 136.2821819782257 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 1.0034620761871338 sec
# 	 2. Constants and Functions are over.	 It takes 0.006994485855102539 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.6755883693695068 sec
# 		 3.2. Team_xA is over.	 It takes 1.3171892166137695 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.6835787296295166 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.05496525764465332 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.04996895790100098 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.050969600677490234 sec
# 		 3.7. TableTeams is over.	 It takes 0.0049970149993896484 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 28.10570001602173 sec
# 		 4.2. Player_xA is over.	 It takes 28.569419860839844 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.5680289268493652 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.6833970546722412 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 5.936344146728516 sec
# 		 5.2. Visualizing futures.	 It takes 0.03697609901428223 sec
# 	 6. Writing to files is over.	 It takes 129.23162984848022 sec
# FPL is created./t It takes 198.98020887374878 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.20085906982421875 sec
# 	 2. Constants and Functions are over.	 It takes 0.0069959163665771484 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.3591632843017578 sec
# 		 3.2. Team_xA is over.	 It takes 0.6276137828826904 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.268218755722046 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.04896998405456543 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.04797029495239258 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.04896998405456543 sec
# 		 3.7. TableTeams is over.	 It takes 0.0049953460693359375 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 26.493691205978394 sec
# 		 4.2. Player_xA is over.	 It takes 26.57364058494568 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.6479854583740234 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.712949514389038 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 5.981318712234497 sec
# 		 5.2. Visualizing futures.	 It takes 0.03797626495361328 sec
# 	 6. Writing to files is over.	 It takes 119.47975206375122 sec
# Understat is created./t It takes 185.5420699119568 sec
# 	 FPL Testing is over.	 It takes 1.243218183517456 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 14.671951532363892 sec
#
#
# The whole program working time is  918.193368434906
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
