# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 221.60556721687317 sec
# 	 Fixtures are over.	 It takes 31.108628511428833 sec
# inputFPL is over.	 It takes 254.47385215759277 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 68.4853343963623 sec
# 	 All Columns Added.	 It takes 0.888455867767334 sec
# inputUnderstat is over.	 It takes 69.37478756904602 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.729560375213623 sec
# 	 2. Constants and Functions are over.	 It takes 0.030981779098510742 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.42473435401916504 sec
# 		 3.2. Team_xA is over.	 It takes 0.3587782382965088 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.6266241073608398 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.05995512008666992 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.07195472717285156 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.06296300888061523 sec
# 		 3.7. TableTeams is over.	 It takes 0.07095742225646973 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 14.269209146499634 sec
# 		 4.2. Player_xA is over.	 It takes 11.116151809692383 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.924431562423706 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.5446610450744629 sec
# 	 5. Writing to files is over.	 It takes 98.76348519325256 sec
# FPL is created./t It takes 128.06143379211426 sec
#
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.36377739906311035 sec
# 	 2. Constants and Functions are over.	 It takes 0.0069942474365234375 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.3641607761383057 sec
# 		 3.2. Team_xA is over.	 It takes 0.4916963577270508 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3347933292388916 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.022985219955444336 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.026985645294189453 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.047971487045288086 sec
# 		 3.7. TableTeams is over.	 It takes 0.01798725128173828 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 13.439720392227173 sec
# 		 4.2. Player_xA is over.	 It takes 12.53827428817749 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.333181619644165 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.5036883354187012 sec
# 	 5. Writing to files is over.	 It takes 64.09272265434265 sec
# Understat is created./t It takes 94.5869390964508 sec
#
# 	 FPL Testing is over.	 It takes 0.38076090812683105 sec
#                  player  element  fixture  minutes  FPL_minutes
# 0             Nick Pope     96.0       70       90            0
# 1        Matthew Lowton     92.0       70       90            0
# 2               Ben Mee     88.0       70       90            0
# 3       James Tarkowski     81.0       70       90            0
# 4        Charlie Taylor     97.0       70       90            0
# 5          Robbie Brady     95.0       70       90            0
# 6       Ashley Westwood     89.0       70       90            0
# 7        Josh Brownhill     98.0       70       90            0
# 8         Dwight McNeil    100.0       70       90            0
# 9            Chris Wood     91.0       70       85            0
# 10        Ashley Barnes     87.0       70       71            0
# 11        Jay Rodriguez     86.0       70       19            0
# 12          Mathew Ryan     70.0       70       90            0
# 13        Tariq Lamptey     77.0       70       90            0
# 14            Ben White     74.0       70       90            0
# 15         Joel Veltman     67.0       70       84            0
# 16         Adam Webster     66.0       70       90            0
# 17             Dan Burn     61.0       70       90            0
# 18          Pascal Groß     57.0       70       90            0
# 19        Yves Bissouma     76.0       70       90            0
# 20         Adam Lallana     54.0       70       90            0
# 21          Neal Maupay     68.0       70       90            0
# 22        Danny Welbeck    588.0       70       87            0
# 23          Karl Darlow    325.0       76       90            0
# 24         Jacob Murphy    497.0       76       80            0
# 25   Federico Fernandez    323.0       76       90            0
# 26         Fabian Schar    334.0       76       90            0
# 27     Jamaal Lascelles    328.0       76       90            0
# 28          Jamal Lewis    513.0       76       90            0
# 29       Sean Longstaff    480.0       76       90            0
# 30        Jeff Hendrick    485.0       76       62            0
# 31       Miguel Almiron    339.0       76       90            0
# 32  Allan Saint-Maximin    338.0       76       90            0
# 33        Callum Wilson    506.0       76       79            0
# 34         Andy Carroll    320.0       76       11            0
# 35    Matthew Longstaff    487.0       76       28            0
# 36        Alex McCarthy    363.0       76       90            0
# 37   Kyle Walker-Peters    375.0       76       90            0
# 38   Jannik Vestergaard    369.0       76       90            0
# 39         Jan Bednarek    376.0       76       90            0
# 40        Jack Stephens    367.0       76       90            0
# 41     Stuart Armstrong    368.0       76       90            0
# 42    Oriol Romeu Vidal    364.0       76       90            0
# 43    James Ward-Prowse    370.0       76       90            0
# 44       Moussa Djenepo    382.0       76       75            0
# 45         Theo Walcott    148.0       76       89            0
# 46            Che Adams    377.0       76       90            0
# 47       Nathan Redmond    365.0       76       15            0
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 6.3080360889434814 sec
# The whole program working time is  553.2759861946106
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
