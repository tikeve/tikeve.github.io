# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 186.96849822998047 sec
# 	 Fixtures are over.	 It takes 32.85276699066162 sec
# inputFPL is over.	 It takes 220.61199951171875 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 50.28655767440796 sec
# 	 All Columns Added.	 It takes 0.5616569519042969 sec
# inputUnderstat is over.	 It takes 50.84921407699585 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.49676084518432617 sec
# 	 2. Constants and Functions are over.	 It takes 0.005993843078613281 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.43620729446411133 sec
# 		 3.2. Team_xA is over.	 It takes 0.40274500846862793 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3887617588043213 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.1082000732421875 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.027985572814941406 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.03197741508483887 sec
# 		 3.7. TableTeams is over.	 It takes 0.01910996437072754 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 12.86188817024231 sec
# 		 4.2. Player_xA is over.	 It takes 14.968761444091797 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.6246120929718018 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.6609792709350586 sec
# 	 4.99. Creating future tables and opponent tables is over.	 It takes 11.101407527923584 sec
# 	 5. Writing to files is over.	 It takes 83.62754678726196 sec
# FPL is created./t It takes 126.7679328918457 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.24083805084228516 sec
# 	 2. Constants and Functions are over.	 It takes 0.012990236282348633 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.4597184658050537 sec
# 		 3.2. Team_xA is over.	 It takes 0.9054405689239502 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3697686195373535 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.02598404884338379 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.024984359741210938 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.02598404884338379 sec
# 		 3.7. TableTeams is over.	 It takes 0.00499725341796875 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 13.877451419830322 sec
# 		 4.2. Player_xA is over.	 It takes 13.974396228790283 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.6056275367736816 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.0613646507263184 sec
# 	 4.99. Creating future tables and opponent tables is over.	 It takes 5.15472936630249 sec
# 	 5. Writing to files is over.	 It takes 84.99858927726746 sec
# Understat is created./t It takes 121.74386382102966 sec
# 	 FPL Testing is over.	 It takes 0.8394632339477539 sec
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 12.23845911026001 sec
#
#
# The whole program working time is  533.1207177639008
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
