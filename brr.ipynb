# %%
''' Main file

    Main module. Runs program() which does pretty much everything + sends mistakes on mail and telegram
    
    
    Uses 3 modules: inputFPL, inputUnderstat, Source
    
    inputFPL downloads data from https://fantasy.premierleague.com/
    inputUnderstat downloads data from https://understat.com/
    Source converts data to suitable pandas tables correctness by running source.test function.
    
    
    Uses no data

'''
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
import sys
from traceback import format_exc
from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    
    start_program = time()    
#     sys.argv = ['', 'full']
    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    print(f'Data Collection Type (sys.argv[1]) is {sys.argv[1]}\n\n')
    runpy.run_module('Check_PRE_SEASON', run_name='smth')
    if sys.argv[1] == 'pre-season':
        print(f"It's stil a pre-season!\n\n")
    
    if (sys.argv[1] != 'nothing')&(sys.argv[1] != 'pre-season'):
        
        runpy.run_module('inputUnderstat', run_name='smth')
        #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
        FPL = Source('FPL', ma_num=7)
        #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
        Understat = Source('Understat', ma_num=7)
        #Tests for the Final tables
        FPL.test()
        Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    print('End')

    
    
    
    
    
    
#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# Indexes are not equal: {768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767}
# Fixtures has changed:
#      event     id
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4     True  False
# ..     ...    ...
# 365   True  False
# 366   True  False
# 367   True  False
# 368   True  False
# 369   True  False
#
# [367 rows x 2 columns]
# Players teams list has changed:
#      team
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 773    20
# 774    20
# 775    20
# 776    20
# 777    20
#
# [778 rows x 1 columns]
# 		Data Collection Type = full
#
# 	Downloading FPL tables is over.	 It takes 321.0617136955261 sec
#
# 	Creating tables is over.	 It takes 89.29904794692993 sec
#
# inputFPL is over.	 It takes 410.3627588748932 sec
#
# Data Collection Type (sys.argv[1]) is full
#
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 111.28096008300781 sec
# 	 All Columns Added.	 It takes 0.3238074779510498 sec
# inputUnderstat is over.	 It takes 111.60476756095886 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.18492388725280762 sec
# 	 2. Constants and Functions are over.	 It takes 0.0009999275207519531 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.2650787830352783 sec
# 		 3.2. Team_xA is over.	 It takes 1.0878312587738037 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.0827574729919434 sec
# 		 3.3.99 Creating coeffitients is over.	 It takes 0.022986650466918945 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.03198671340942383 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.030977964401245117 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.031982421875 sec
# 		 3.7. TableTeams is over.	 It takes 0.0039980411529541016 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 39.28334832191467 sec
# 		 4.2. Player_xA is over.	 It takes 39.084017515182495 sec
# 		 4.2.99 Creating coeffitients is over.	 It takes 0.32988500595092773 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.7335591316223145 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.7605793476104736 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 0.6056332588195801 sec
# 		 5.2. Visualizing futures.	 It takes 0.762568473815918 sec
# 	 6. Writing to files is over.	 It takes 74.8168785572052 sec
# FPL is created./t It takes 160.12760663032532 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.08031558990478516 sec
# 	 2. Constants and Functions are over.	 It takes 0.0 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.2119338512420654 sec
# 		 3.2. Team_xA is over.	 It takes 1.045577049255371 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.0256578922271729 sec
# 		 3.3.99 Creating coeffitients is over.	 It takes 0.022986888885498047 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.03198742866516113 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.03296518325805664 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.03697991371154785 sec
# 		 3.7. TableTeams is over.	 It takes 0.003997802734375 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 36.649341344833374 sec
# 		 4.2. Player_xA is over.	 It takes 36.83703827857971 sec
# 		 4.2.99 Creating coeffitients is over.	 It takes 0.2888662815093994 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.7215871810913086 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.7815635204315186 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 0.567335844039917 sec
# 		 5.2. Visualizing futures.	 It takes 0.7445745468139648 sec
# 	 6. Writing to files is over.	 It takes 75.61931252479553 sec
# Understat is created./t It takes 155.7090232372284 sec
# 	 FPL Testing is over.	 It takes 0.29383087158203125 sec
#                            player  element  fixture  minutes  FPL_minutes
# 0   Emerson Leite de Souza Junior    445.0       32       47            0
# 1   Emerson Leite de Souza Junior    445.0       47        1           90
# 2   Emerson Leite de Souza Junior    445.0       54       90            0
# 3   Emerson Leite de Souza Junior    445.0       90       12            0
# 4   Emerson Leite de Souza Junior    445.0      108       62            0
# 5                      Matty Cash     43.0      140       79           68
# 6              Leander Dendoncker    479.0      140       79           68
# 7          Emiliano Buendia Stati     42.0      140       71           60
# 8                     Leon Bailey     45.0      140       71           60
# 9                     Sven Botman    377.0      140       81           70
# 10                    Joe Willock    373.0      140       81           70
# 11  Emerson Leite de Souza Junior    445.0      179       67            0
# 12  Emerson Leite de Souza Junior    445.0      210       83            0
# 13  Emerson Leite de Souza Junior    445.0      217       90            0
# 14  Emerson Leite de Souza Junior    445.0      230       90            0
# 15  Emerson Leite de Souza Junior    445.0      254       90            0
# 16  Emerson Leite de Souza Junior    445.0      270       90            0
# 17  Emerson Leite de Souza Junior    445.0      290       90            0
# 18  Emerson Leite de Souza Junior    445.0       70       90            0
# 19  Emerson Leite de Souza Junior    445.0      335       51            0
# 20  Emerson Leite de Souza Junior    445.0      277       90            0
# 21  Emerson Leite de Souza Junior    445.0      353       90            0
# 22  Emerson Leite de Souza Junior    445.0      369       90            0
# 23  Emerson Leite de Souza Junior    445.0      378       18            0
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 17.41414523124695 sec
#
#
# The whole program working time is  855.6247818470001
# End

# %%
import constti
constti.head_header_script()
# Out:
# {'__name__': '__main__',
#  '__doc__': ' Main file\n\n    Main module. Runs program(), does some testing, sends mistakes on mail and telegram\n    \n    \n    Uses 3 modules: inputFPL, inputUnderstat, Source\n    \n    inputFPL downloads data from https://fantasy.premierleague.com/\n    inputUnderstat downloads data from https://understat.com/\n    Source converts data to suitable pandas tables correctness by running source.test function.\n    \n    \n    Uses no data\n\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '\'\'\' Main file\n\n    Main module. Runs program(), does some testing, sends mistakes on mail and telegram\n    \n    \n    Uses 3 modules: inputFPL, inputUnderstat, Source\n    \n    inputFPL downloads data from https://fantasy.premierleague.com/\n    inputUnderstat downloads data from https://understat.com/\n    Source converts data to suitable pandas tables correctness by running source.test function.\n    \n    \n    Uses no data\n\n\'\'\'\n\n\n# Основной файл.\n#Скачивает данные через модули inputfpl1.py и inputUnderstat\n#Преобразовывет их в таблицы таблицы через конструктор класса Source\n#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.\nimport yagmail\nimport requests\nimport os\nfrom dotenv import load_dotenv\nfrom time import time\nimport runpy\nimport sys\nfrom traceback import format_exc\n\nfrom Source import Source\nimport constti\n\n# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source\ndef program():\n    start_program = time()\n    \n    sys.argv = [\'\', \'*\']\n    #Loading Data from FPL and Understat\n    runpy.run_module(\'inputFPL\', run_name=\'smth\')\n    runpy.run_module(\'inputUnderstat\', run_name=\'smth\')\n    print(f\' sys.argv is {sys.argv[1]}\')\n\n    \n    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average\n    FPL = Source(\'FPL\', ma_num=7)\n    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average\n    Understat = Source(\'Understat\', ma_num=7)\n    #Tests for the Final tables\n    FPL.test()\n    Understat.test()\n    \n    print(f\'The whole program working time is  {time() - start_program}\')\n    #display(FPL.PlayerThreatAd)\n    print(\'End\')\n\n#send mail or not\nwith_mail = 1\n\n# Если отправлять ошибки на почту\nif with_mail:\n    try:\n        program()\n    except Exception as e:\n        \n        err = format_exc()\n        \n        #Reading passwords from .env\n        load_dotenv()\n        telegram_API = os.getenv(\'telegram\')\n        mail_pass = os.getenv(\'imonyapa_mail\')\n        \n        #Sending Error message to mail\n        FROM = \'imonyapa@gmail.com\'\n        TO = \'constti@gmail.com\'\n        SUBJECT = \'1stpy\'\n        TEXT=f\'{e} \\n\\n\\n {err}\'\n        yag = yagmail.SMTP(FROM, mail_pass)\n        yag.send(TO, SUBJECT, TEXT)\n        \n        #Sending Error message with telegram\n        url = f\'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text=\'+TEXT\n\n        http_proxy  = "http://10.10.1.10:3128"\n        https_proxy = "https://51.178.59.37:3128"\n        ftp_proxy   = "ftp://10.10.1.10:3128"\n\n        proxyDict = { \n                      "http"  : http_proxy, \n                      "https" : https_proxy, \n                      "ftp"   : ftp_proxy\n                    }\n        \n        #Proxy is dead(((\n        p=requests.get(url)#, proxies=proxyDict)\n        \n        print(TEXT)\n# Без отправки ошибок на почту        \nelse: program()',
#   'globals()\nsys.argv',
#   'globals()'],
#  '_oh': {2: ['', '*']},
#  '_dh': ['c:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['',
#   '\'\'\' Main file\n\n    Main module. Runs program(), does some testing, sends mistakes on mail and telegram\n    \n    \n    Uses 3 modules: inputFPL, inputUnderstat, Source\n    \n    inputFPL downloads data from https://fantasy.premierleague.com/\n    inputUnderstat downloads data from https://understat.com/\n    Source converts data to suitable pandas tables correctness by running source.test function.\n    \n    \n    Uses no data\n\n\'\'\'\n\n\n# Основной файл.\n#Скачивает данные через модули inputfpl1.py и inputUnderstat\n#Преобразовывет их в таблицы таблицы через конструктор класса Source\n#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.\nimport yagmail\nimport requests\nimport os\nfrom dotenv import load_dotenv\nfrom time import time\nimport runpy\nimport sys\nfrom traceback import format_exc\n\nfrom Source import Source\nimport constti\n\n# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source\ndef program():\n    start_program = time()\n    \n    sys.argv = [\'\', \'*\']\n    #Loading Data from FPL and Understat\n    runpy.run_module(\'inputFPL\', run_name=\'smth\')\n    runpy.run_module(\'inputUnderstat\', run_name=\'smth\')\n    print(f\' sys.argv is {sys.argv[1]}\')\n\n    \n    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average\n    FPL = Source(\'FPL\', ma_num=7)\n    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average\n    Understat = Source(\'Understat\', ma_num=7)\n    #Tests for the Final tables\n    FPL.test()\n    Understat.test()\n    \n    print(f\'The whole program working time is  {time() - start_program}\')\n    #display(FPL.PlayerThreatAd)\n    print(\'End\')\n\n#send mail or not\nwith_mail = 1\n\n# Если отправлять ошибки на почту\nif with_mail:\n    try:\n        program()\n    except Exception as e:\n        \n        err = format_exc()\n        \n        #Reading passwords from .env\n        load_dotenv()\n        telegram_API = os.getenv(\'telegram\')\n        mail_pass = os.getenv(\'imonyapa_mail\')\n        \n        #Sending Error message to mail\n        FROM = \'imonyapa@gmail.com\'\n        TO = \'constti@gmail.com\'\n        SUBJECT = \'1stpy\'\n        TEXT=f\'{e} \\n\\n\\n {err}\'\n        yag = yagmail.SMTP(FROM, mail_pass)\n        yag.send(TO, SUBJECT, TEXT)\n        \n        #Sending Error message with telegram\n        url = f\'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text=\'+TEXT\n\n        http_proxy  = "http://10.10.1.10:3128"\n        https_proxy = "https://51.178.59.37:3128"\n        ftp_proxy   = "ftp://10.10.1.10:3128"\n\n        proxyDict = { \n                      "http"  : http_proxy, \n                      "https" : https_proxy, \n                      "ftp"   : ftp_proxy\n                    }\n        \n        #Proxy is dead(((\n        p=requests.get(url)#, proxies=proxyDict)\n        \n        print(TEXT)\n# Без отправки ошибок на почту        \nelse: program()',
#   'globals()\nsys.argv',
#   'globals()'],
#  'Out': {2: ['', '*']},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001303366E748>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x13035372748>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x13035372748>,
#  '_': ['', '*'],
#  '__': '',
#  '___': '',
#  '_i': 'globals()\nsys.argv',
#  '_ii': '\'\'\' Main file\n\n    Main module. Runs program(), does some testing, sends mistakes on mail and telegram\n    \n    \n    Uses 3 modules: inputFPL, inputUnderstat, Source\n    \n    inputFPL downloads data from https://fantasy.premierleague.com/\n    inputUnderstat downloads data from https://understat.com/\n    Source converts data to suitable pandas tables correctness by running source.test function.\n    \n    \n    Uses no data\n\n\'\'\'\n\n\n# Основной файл.\n#Скачивает данные через модули inputfpl1.py и inputUnderstat\n#Преобразовывет их в таблицы таблицы через конструктор класса Source\n#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.\nimport yagmail\nimport requests\nimport os\nfrom dotenv import load_dotenv\nfrom time import time\nimport runpy\nimport sys\nfrom traceback import format_exc\n\nfrom Source import Source\nimport constti\n\n# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source\ndef program():\n    start_program = time()\n    \n    sys.argv = [\'\', \'*\']\n    #Loading Data from FPL and Understat\n    runpy.run_module(\'inputFPL\', run_name=\'smth\')\n    runpy.run_module(\'inputUnderstat\', run_name=\'smth\')\n    print(f\' sys.argv is {sys.argv[1]}\')\n\n    \n    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average\n    FPL = Source(\'FPL\', ma_num=7)\n    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average\n    Understat = Source(\'Understat\', ma_num=7)\n    #Tests for the Final tables\n    FPL.test()\n    Understat.test()\n    \n    print(f\'The whole program working time is  {time() - start_program}\')\n    #display(FPL.PlayerThreatAd)\n    print(\'End\')\n\n#send mail or not\nwith_mail = 1\n\n# Если отправлять ошибки на почту\nif with_mail:\n    try:\n        program()\n    except Exception as e:\n        \n        err = format_exc()\n        \n        #Reading passwords from .env\n        load_dotenv()\n        telegram_API = os.getenv(\'telegram\')\n        mail_pass = os.getenv(\'imonyapa_mail\')\n        \n        #Sending Error message to mail\n        FROM = \'imonyapa@gmail.com\'\n        TO = \'constti@gmail.com\'\n        SUBJECT = \'1stpy\'\n        TEXT=f\'{e} \\n\\n\\n {err}\'\n        yag = yagmail.SMTP(FROM, mail_pass)\n        yag.send(TO, SUBJECT, TEXT)\n        \n        #Sending Error message with telegram\n        url = f\'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text=\'+TEXT\n\n        http_proxy  = "http://10.10.1.10:3128"\n        https_proxy = "https://51.178.59.37:3128"\n        ftp_proxy   = "ftp://10.10.1.10:3128"\n\n        proxyDict = { \n                      "http"  : http_proxy, \n                      "https" : https_proxy, \n                      "ftp"   : ftp_proxy\n                    }\n        \n        #Proxy is dead(((\n        p=requests.get(url)#, proxies=proxyDict)\n        \n        print(TEXT)\n# Без отправки ошибок на почту        \nelse: program()',
#  '_iii': '',
#  '_i1': '\'\'\' Main file\n\n    Main module. Runs program(), does some testing, sends mistakes on mail and telegram\n    \n    \n    Uses 3 modules: inputFPL, inputUnderstat, Source\n    \n    inputFPL downloads data from https://fantasy.premierleague.com/\n    inputUnderstat downloads data from https://understat.com/\n    Source converts data to suitable pandas tables correctness by running source.test function.\n    \n    \n    Uses no data\n\n\'\'\'\n\n\n# Основной файл.\n#Скачивает данные через модули inputfpl1.py и inputUnderstat\n#Преобразовывет их в таблицы таблицы через конструктор класса Source\n#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.\nimport yagmail\nimport requests\nimport os\nfrom dotenv import load_dotenv\nfrom time import time\nimport runpy\nimport sys\nfrom traceback import format_exc\n\nfrom Source import Source\nimport constti\n\n# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source\ndef program():\n    start_program = time()\n    \n    sys.argv = [\'\', \'*\']\n    #Loading Data from FPL and Understat\n    runpy.run_module(\'inputFPL\', run_name=\'smth\')\n    runpy.run_module(\'inputUnderstat\', run_name=\'smth\')\n    print(f\' sys.argv is {sys.argv[1]}\')\n\n    \n    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average\n    FPL = Source(\'FPL\', ma_num=7)\n    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average\n    Understat = Source(\'Understat\', ma_num=7)\n    #Tests for the Final tables\n    FPL.test()\n    Understat.test()\n    \n    print(f\'The whole program working time is  {time() - start_program}\')\n    #display(FPL.PlayerThreatAd)\n    print(\'End\')\n\n#send mail or not\nwith_mail = 1\n\n# Если отправлять ошибки на почту\nif with_mail:\n    try:\n        program()\n    except Exception as e:\n        \n        err = format_exc()\n        \n        #Reading passwords from .env\n        load_dotenv()\n        telegram_API = os.getenv(\'telegram\')\n        mail_pass = os.getenv(\'imonyapa_mail\')\n        \n        #Sending Error message to mail\n        FROM = \'imonyapa@gmail.com\'\n        TO = \'constti@gmail.com\'\n        SUBJECT = \'1stpy\'\n        TEXT=f\'{e} \\n\\n\\n {err}\'\n        yag = yagmail.SMTP(FROM, mail_pass)\n        yag.send(TO, SUBJECT, TEXT)\n        \n        #Sending Error message with telegram\n        url = f\'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text=\'+TEXT\n\n        http_proxy  = "http://10.10.1.10:3128"\n        https_proxy = "https://51.178.59.37:3128"\n        ftp_proxy   = "ftp://10.10.1.10:3128"\n\n        proxyDict = { \n                      "http"  : http_proxy, \n                      "https" : https_proxy, \n                      "ftp"   : ftp_proxy\n                    }\n        \n        #Proxy is dead(((\n        p=requests.get(url)#, proxies=proxyDict)\n        \n        print(TEXT)\n# Без отправки ошибок на почту        \nelse: program()',
#  'yagmail': <module 'yagmail' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\yagmail\\__init__.py'>,
#  'requests': <module 'requests' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\requests\\__init__.py'>,
#  'os': <module 'os' from 'C:\\ProgramData\\Anaconda3\\lib\\os.py'>,
#  'load_dotenv': <function dotenv.main.load_dotenv(dotenv_path=None, stream=None, verbose=False, override=False, interpolate=True, **kwargs)>,
#  'time': <function time.time>,
#  'runpy': <module 'runpy' from 'C:\\ProgramData\\Anaconda3\\lib\\runpy.py'>,
#  'sys': <module 'sys' (built-in)>,
#  'format_exc': <function traceback.format_exc(limit=None, chain=True)>,
#  'Source': Source.Source,
#  'constti': <module 'constti' from 'c:\\Users\\const\\Documents\\GitHub\\tikeve.github.io\\constti.py'>,
#  'program': <function __main__.program()>,
#  'with_mail': 1,
#  '_i2': 'globals()\nsys.argv',
#  '_2': ['', '*'],
#  '_i3': 'globals()'}

# %% [markdown]
# ##### import inputFPL
# import runpy
# a = runpy.run_module('inputFPL', run_name='smth')
