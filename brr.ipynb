# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 256.48808455467224 sec
# 	 Fixtures are over.	 It takes 56.076480865478516 sec
# inputFPL is over.	 It takes 314.0079154968262 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 109.71874618530273 sec
# 	 All Columns Added.	 It takes 1.331953525543213 sec
# inputUnderstat is over.	 It takes 111.05069971084595 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.7214367389678955 sec
# 	 2. Constants and Functions are over.	 It takes 0.008992433547973633 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.7427492141723633 sec
# 		 3.2. Team_xA is over.	 It takes 1.1122963428497314 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.5556535720825195 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.15612483024597168 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.09892606735229492 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.1478900909423828 sec
# 		 3.7. TableTeams is over.	 It takes 0.027240514755249023 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 22.062652349472046 sec
# 		 4.2. Player_xA is over.	 It takes 22.601070880889893 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.996366024017334 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.5360500812530518 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 8.03951644897461 sec
# 		 5.2. Visualizing futures.	 It takes 0.05687260627746582 sec
# 	 6. Writing to files is over.	 It takes 206.15837264060974 sec
# FPL is created./t It takes 265.0252277851105 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.9297182559967041 sec
# 	 2. Constants and Functions are over.	 It takes 0.04896688461303711 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.6256122589111328 sec
# 		 3.2. Team_xA is over.	 It takes 1.9318115711212158 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 2.1027004718780518 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.1049346923828125 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.10593485832214355 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.10993218421936035 sec
# 		 3.7. TableTeams is over.	 It takes 0.017993927001953125 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 31.694138765335083 sec
# 		 4.2. Player_xA is over.	 It takes 26.55781102180481 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.8428611755371094 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.8428640365600586 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 8.589831590652466 sec
# 		 5.2. Visualizing futures.	 It takes 0.0319826602935791 sec
# 	 6. Writing to files is over.	 It takes 111.9780957698822 sec
# Understat is created./t It takes 188.5241825580597 sec
# 	 FPL Testing is over.	 It takes 0.6423940658569336 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 10.49247431755066 sec
#
#
# The whole program working time is  889.8116896152496
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
