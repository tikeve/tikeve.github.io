# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 279.564706325531 sec
# C:\Users\const\Documents\GitHub\tikeve.github.io\Brr_functions.py:78: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return table.applymap(lambda x: np.nan if x == '' else    x if type(x) in (int, np.int64,  float, np.float64, list, np.ndarray, str) else np.nan)
# 	 Fixtures are over.	 It takes 62.20830178260803 sec
# inputFPL is over.	 It takes 343.8373501300812 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 100.03047847747803 sec
# 	 All Columns Added.	 It takes 0.6525933742523193 sec
# inputUnderstat is over.	 It takes 100.684072971344 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 1.1820108890533447 sec
# 	 2. Constants and Functions are over.	 It takes 0.01900196075439453 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.5248339176177979 sec
# 		 3.2. Team_xA is over.	 It takes 0.5456640720367432 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.0953269004821777 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.12021565437316895 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.041971445083618164 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.03097844123840332 sec
# 		 3.7. TableTeams is over.	 It takes 0.021016597747802734 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 18.35135245323181 sec
# 		 4.2. Player_xA is over.	 It takes 20.41408658027649 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.6360082626342773 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.6850385665893555 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 6.724657773971558 sec
# 		 5.2. Visualizing futures.	 It takes 0.045787811279296875 sec
# 	 6. Writing to files is over.	 It takes 110.06875967979431 sec
# FPL is created./t It takes 162.51070189476013 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.5228672027587891 sec
# 	 2. Constants and Functions are over.	 It takes 0.007992744445800781 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 1.1562983989715576 sec
# 		 3.2. Team_xA is over.	 It takes 1.093315601348877 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 1.3481693267822266 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.057964324951171875 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.07795071601867676 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.03797745704650879 sec
# 		 3.7. TableTeams is over.	 It takes 0.009993553161621094 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 25.933013200759888 sec
# 		 4.2. Player_xA is over.	 It takes 19.74582815170288 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.8134984970092773 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.5610356330871582 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 7.64166522026062 sec
# 		 5.2. Visualizing futures.	 It takes 0.07795047760009766 sec
# 	 6. Writing to files is over.	 It takes 100.28886389732361 sec
# Understat is created./t It takes 160.38038229942322 sec
# 	 FPL Testing is over.	 It takes 0.8114988803863525 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 9.115129470825195 sec
#
#
# The whole program working time is  777.4033620357513
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
