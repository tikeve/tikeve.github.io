# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()

    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 242.49319982528687 sec
# C:\Users\const\Documents\GitHub\tikeve.github.io\Brr_functions.py:78: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return table.applymap(lambda x: np.nan if x == '' else    x if type(x) in (int, np.int64,  float, np.float64, list, np.ndarray, str) else np.nan)
# 	 Fixtures are over.	 It takes 63.93994379043579 sec
# inputFPL is over.	 It takes 309.60175347328186 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 145.12758803367615 sec
# 	 All Columns Added.	 It takes 3.1780426502227783 sec
# inputUnderstat is over.	 It takes 148.30563068389893 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 2.457486867904663 sec
# 	 2. Constants and Functions are over.	 It takes 0.01598644256591797 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 2.14267897605896 sec
# 		 3.2. Team_xA is over.	 It takes 1.960792064666748 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 2.0047643184661865 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.12891936302185059 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.07495474815368652 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.06096148490905762 sec
# 		 3.7. TableTeams is over.	 It takes 0.009994029998779297 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 74.08132100105286 sec
# 		 4.2. Player_xA is over.	 It takes 30.313305616378784 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 2.022752046585083 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 1.7639141082763672 sec
# 	 4.99. Creating future tables and opponent tables is over.	 It takes 11.372707843780518 sec
# 	 5. Writing to files is over.	 It takes 116.42555046081543 sec
# FPL is created./t It takes 244.8490936756134 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.7405226230621338 sec
# 	 2. Constants and Functions are over.	 It takes 0.010991573333740234 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.4187455177307129 sec
# 		 3.2. Team_xA is over.	 It takes 0.4217400550842285 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.8844704627990723 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.07893991470336914 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.07994508743286133 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.08893227577209473 sec
# 		 3.7. TableTeams is over.	 It takes 0.015989303588867188 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 16.311935901641846 sec
# 		 4.2. Player_xA is over.	 It takes 16.50182843208313 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 1.1244332790374756 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.8734605312347412 sec
# 	 4.99. Creating future tables and opponent tables is over.	 It takes 6.334009408950806 sec
# 	 5. Writing to files is over.	 It takes 90.66467618942261 sec
# Understat is created./t It takes 134.55663418769836 sec
# 	 FPL Testing is over.	 It takes 1.1382973194122314 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 10.95757269859314 sec
#
#
# The whole program working time is  849.5470943450928
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
