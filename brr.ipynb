# %%
# Основной файл.
#Скачивает данные через модули inputfpl1.py и inputUnderstat
#Преобразовывет их в таблицы таблицы через конструктор класса Source
#Ф-ция program делает все необходомое, нужна чтобы использовать её по желанию с почтой(telegram) и без.
import yagmail
import requests
import os
from dotenv import load_dotenv
from time import time
import runpy
import sys
from traceback import format_exc

from Source import Source
import constti

# Скачаивает и записывает в таблицы все данные. Выводит в файоы папки input и output/Source
def program():
    start_program = time()
    
    sys.argv = ['', 'full']
    #Loading Data from FPL and Understat
    runpy.run_module('inputFPL', run_name='smth')
    runpy.run_module('inputUnderstat', run_name='smth')

    
    #Берет данные fantasy.premierleague.com(FPl) и делает из них финальные таблицы. ma_num - gameweeks to average
    FPL = Source('FPL', ma_num=7)
    #Takes data from understat.com(Understat) and builds table out of them. ma_num - gameweeks to average
    Understat = Source('Understat', ma_num=7)
    #Tests for the Final tables
    FPL.test()
    Understat.test()
    
    print(f'The whole program working time is  {time() - start_program}')
    #display(FPL.PlayerThreatAd)
    print('End')

#send mail or not
with_mail = 1

# Если отправлять ошибки на почту
if with_mail:
    try:
        program()
    except Exception as e:
        
        err = format_exc()
        
        #Reading passwords from .env
        load_dotenv()
        telegram_API = os.getenv('telegram')
        mail_pass = os.getenv('imonyapa_mail')
        
        #Sending Error message to mail
        FROM = 'imonyapa@gmail.com'
        TO = 'constti@gmail.com'
        SUBJECT = '1stpy'
        TEXT=f'{e} \n\n\n {err}'
        yag = yagmail.SMTP(FROM, mail_pass)
        yag.send(TO, SUBJECT, TEXT)
        
        #Sending Error message with telegram
        url = f'https://api.telegram.org/bot1182664319:{telegram_API}/sendMessage?chat_id=108651591&text='+TEXT

        http_proxy  = "http://10.10.1.10:3128"
        https_proxy = "https://51.178.59.37:3128"
        ftp_proxy   = "ftp://10.10.1.10:3128"

        proxyDict = { 
                      "http"  : http_proxy, 
                      "https" : https_proxy, 
                      "ftp"   : ftp_proxy
                    }
        
        #Proxy is dead(((
        p=requests.get(url)#, proxies=proxyDict)
        
        print(TEXT)
# Без отправки ошибок на почту        
else: program()
# Out:
# Start inputFPL:
# System var is - full
# HTTPSConnectionPool(host='fantasy.premierleague.com', port=443): Max retries exceeded with url: /api/element-summary/467/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001A32F0C77B8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
# 	Downloading FPL tables is over.	 It takes 178.80906581878662 sec
#
# 	Checking equalities is over.	 It takes 0.5966482162475586 sec
#
# 	data_collection_type = full
#
# 	Creating tables is over.	 It takes 36.30621862411499 sec
#
# inputFPL is over.	 It takes 215.71392273902893 sec
#
# Start inputUnderstat:
# 	 All Data Downloaded.	 It takes 62.882405042648315 sec
# 	 All Columns Added.	 It takes 0.6376349925994873 sec
# inputUnderstat is over.	 It takes 63.522042989730835 sec
#
# Start Creating FPL Tables:
# 	 1. Reading files from FPL is over.	 It takes 0.0969395637512207 sec
# 	 2. Constants and Functions are over.	 It takes 0.002997875213623047 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.4207496643066406 sec
# 		 3.2. Team_xA is over.	 It takes 0.41147375106811523 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.4107546806335449 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.020987987518310547 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.0199887752532959 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.020987749099731445 sec
# 		 3.7. TableTeams is over.	 It takes 0.003997802734375 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 12.160720825195312 sec
# 		 4.2. Player_xA is over.	 It takes 13.65726613998413 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.42375779151916504 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.4617335796356201 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 1.730086326599121 sec
# 		 5.2. Visualizing futures.	 It takes 0.02997565269470215 sec
# 	 6. Writing to files is over.	 It takes 24.68961238861084 sec
# FPL is created./t It takes 54.56402087211609 sec
# Start Creating Understat Tables:
# 	 1. Reading files from Understat is over.	 It takes 0.15459084510803223 sec
# 	 2. Constants and Functions are over.	 It takes 0.0030019283294677734 sec
# 	 3. Calculating team tables
# 		 3.1. Team_xG is over.	 It takes 0.3977692127227783 sec
# 		 3.2. Team_xA is over.	 It takes 0.40475940704345703 sec
# 		 3.3. Team_Opponent_xG is over.	 It takes 0.3957860469818115 sec
# 		 3.4. Team_xG_Ad is over.	 It takes 0.02098369598388672 sec
# 		 3.5. Team_xA_Ad is over.	 It takes 0.019988298416137695 sec
# 		 3.6. Team_Opponent_xG_Ad is over.	 It takes 0.0199887752532959 sec
# 		 3.7. TableTeams is over.	 It takes 0.002997875213623047 sec
# 	 4. Calculating player tables
# 		 4.1. Player_xG is over.	 It takes 11.52402138710022 sec
# 		 4.2. Player_xA is over.	 It takes 11.878717184066772 sec
# 		 4.3. Player_xG_Ad is over.	 It takes 0.3787875175476074 sec
# 		 4.4. Player_xA_Ad is over.	 It takes 0.3677847385406494 sec
# 	 5. Creating future tables and opponent tables.
# 		 5.1. Calculating futures.	 It takes 1.5121324062347412 sec
# 		 5.2. Visualizing futures.	 It takes 0.018979549407958984 sec
# 	 6. Writing to files is over.	 It takes 23.472655057907104 sec
# Understat is created./t It takes 50.57495903968811 sec
# 	 FPL Testing is over.	 It takes 0.21687912940979004 sec
#                        player  element  fixture  minutes  FPL_minutes
# 0      Daniel Castelo Podence    469.0       89       80           69
# 1                 Fabio Silva    504.0       89       74           63
# 2  David Luiz Moreira Marinho      3.0       89       56           45
# 3     Willian Borges Da Silva    478.0       89       75           64
# 4                 Rob Holding     16.0       89       34           45
# Empty DataFrame
# Columns: []
# Index: []
# 	 Understat Testing is over.	 It takes 5.991859197616577 sec
#
#
# The whole program working time is  390.58770775794983
# End

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\const\\Documents\\GitHub\\tikeve.github.io'],
#  'In': ['', 'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001EFD7324470>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1efd7b4ad68>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'globals()'}

# %%
import inputFPL
import runpy
a = runpy.run_module('inputFPL', run_name='smth')
# Out:
# Start inputFPL:
# 	 Downloads FPL is over.	 It takes 166.40240502357483 sec
# 	 Fixtures are over.	 It takes 59.91786503791809 sec
# inputFPL is over.	 It takes 226.9049255847931 sec
