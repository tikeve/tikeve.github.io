# %%
import numpy as np
x = np.array([9,3,8,5,9])
x = np.array([2,8,3,5,2,5,2,6,3,5,2,1])
x = np.array([0,0,1,1,1,2,2])
((x-x.mean())**2).sum()/(len(x)-1)
(2/3)**0.5
# Out:
# 0.816496580927726

# %%
(3-8.2**0.5)/4
x = np.array([1,1,2,3,5,5,6])
np.quantile(x,0.2)
(2-3.6**0.5)/2
# Out:
# 0.05131670194948623

# %%
import math

# %%
(math.comb(11,9)+11+1)/2**11
# Out:
# 0.03271484375

# %%
67/2048 * 2
# Out:
# 0.0654296875

# %%
p = 1*(1/6)**5 + 5*5*(1/6)**5 + 10*25*(1/6)**5
p
# Out:
# 0.03549382716049382

# %%
1*(1/6)**5 + 5*5*(1/6)**5 + 10*25*(1/6)**5 + 10*125*(1/6)**5
# Out:
# 0.19624485596707814

# %%
(1+5*3 + 10*9)*(1/4)**5
# Out:
# 0.103515625

# %%
1/64
# Out:
# 0.015625

# %%
1 - (63/64)**10
# Out:
# 0.1457091502359843

# %%
(math.comb(11,8) + math.comb(11,9)+11+1)/2**11
# Out:
# 0.11328125

# %%
p = 12/2**11
p = 67/2048
1 - (1-p)**50
# Out:
# 0.8104489643002506

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import ttest_1samp

# %%
sample = [1,3,5,2,4,1,4,4,5,6,5,3,1,3,3,4,20]
mu0 = 2
t_obs = ttest_1samp(sample, mu0)[0]
t_obs
# Out:
# 2.2559838697729964

# %%
np.std(sample, ddof=1)
# Out:
# 1.5315313367000094

# %%
from scipy.stats import t
x= np.linspace(-5,5)
T = t(df=len(sample) - 1)
plt.plot(x,T.pdf(x))
x_left = np.linspace(-5,-t_obs, 200)
x_right = np.linspace(t_obs,5,200)
plt.fill_between(x_left, T.pdf(x_left))
plt.fill_between(x_right, T.pdf(x_right))

# %%
T.cdf(-t_obs)*2
# Out:
# 0.03842172793861779

# %%
from scipy.stats import ttest_1samp, t
import numpy as np
X = np.array([165, 170, 175, 180, 185, 185, 190, 195, 200, 210])
print(X.mean())
ttest_1samp(X, 175)
# Out:
# 185.5
# Ttest_1sampResult(statistic=2.400108850942297, pvalue=0.039890766746082586)

# %%
M =39250
print((1900/5000)*5)
2*(1-t(24).cdf(1900/5000*5))
# Out:
# 1.9
# 0.06951310490361085

# %%
X = np.array([11,14,15,14,14])
X = np.array([8,12,10,12,9])
M = 12
(1-ttest_1samp(X,12)[1]/2)
# Out:
# 0.9561774117483027

# %%
X.mean()
# Out:
# 10.2

# %%
X = np.array([2, 4, 6, 1, 3, 1, 4])
Y = np.array([3, 6, 2, 5, 7, 7])
